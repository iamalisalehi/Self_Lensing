# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io
import lightkurve as lk
from matplotlib import rc

rc('font', **{'family':'serif', 'serif':['Helvetica']})
rc('text', usetex=True)
plt.rcParams.update({'font.size': 14})

import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
#lc = tpf[2].to_lightcurve(aperture_mask='all')
#lc.plot()

# %%
#lc = lk.search_lightcurve('TIC 153123772', mission='Tess', author='TESS-SPOC').download_all().stitch()
lc = lk.search_lightcurve('TIC 153123772', mission='Tess', author="TESS-SPOC").download_all(flux_column='pdcsap_flux').stitch()
lc
# Out:
# <TessLightCurve length=8053 LABEL="TIC 153123772" SECTOR=33 AUTHOR=TESS-SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                                   ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1468.3064239016753  9.9527305e-01 ...  1.7502768e-02 -2.4648916e-02
# 1468.3272573954252  9.9561495e-01 ...  1.8511789e-02 -2.3870818e-02
# 1468.3480908887088  9.9581397e-01 ...  1.8948594e-02 -2.5356350e-02
# 1468.3689243808287  9.9642819e-01 ...  2.0482592e-02 -2.2824815e-02
# 1468.4105913629735  9.9756551e-01 ...  1.9455979e-02 -2.6622795e-02
#  1468.431424852533  9.9875432e-01 ...  2.0170406e-02 -2.6379645e-02
# 1468.4522583413925  9.9874490e-01 ...  1.9391233e-02 -2.6757816e-02
# 1468.4730918295538  1.0000378e+00 ...  1.9739112e-02 -2.7448505e-02
# 1468.4939253167852  1.0014210e+00 ...  1.9352732e-02 -2.7975807e-02
#                ...            ... ...            ...            ...
#  2227.514106753333  1.0005527e+00 ... -3.2557394e-02  1.6931977e-02
#  2227.521050976281  1.0012245e+00 ... -3.3682585e-02  1.7160721e-02
#  2227.527995199228  1.0005686e+00 ... -3.2640222e-02  1.7543199e-02
# 2227.5349394221757  9.9974430e-01 ... -3.1337898e-02  1.8822709e-02
#  2227.541883644891  9.9941075e-01 ... -3.0785665e-02  2.1033484e-02
#  2227.548827867838  1.0002817e+00 ... -3.2181311e-02  1.9198403e-02
#  2227.555772090552  9.9967492e-01 ... -3.1750869e-02  1.9178363e-02
#  2227.562716313267  1.0013913e+00 ... -3.4119152e-02  1.5718535e-02
# 2227.5696605359817  1.0006453e+00 ... -3.3753980e-02  1.7836681e-02

# %%
search_result = lk.search_lightcurve('TIC 153123772', mission='Tess',author="TESS-SPOC")
lc_collection = search_result[1:].download_all(flux_column='pdcsap_flux').stitch()
lc = lc_collection
p, t0 = 11.393, 2209.3
foldlc = lc.fold(period=p, epoch_time=None)
#ax1=plt.subplots(figsize=(8, 6))
foldlc.plot_river(bin_points=5, method='median')
fig = plt.gcf()
fig.tight_layout(pad=0.0)
plt.show()
#fig.savefig("riverplot.jpg", dpi=200)
# Out:
# /tmp/ipython-input-7-1565847890.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout(pad=0.0)
